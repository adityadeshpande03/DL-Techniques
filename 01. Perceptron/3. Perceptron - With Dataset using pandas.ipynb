# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
X = df[['cgpa','resume_score']].values
y = df['placed'].values

# %%
df['placed'] = df['placed'].replace({0: -1})

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.scatter(X[:,0], X[:,1], c=y, cmap='winter', s=100)

# %%
def perceptron(X,y):
    w1=w2=b=1
    lr=0.1

    for j in range(1000):
        for i in range(X.shape[0]):
            z = w1 * X[i][0] + w2 * X[i][1] + b 
            if z * y[i] < 0:
                w1 = w1 + lr*y[i]*X[i][0]
                w2 = w2 + lr*y[i]*X[i][1]
                b = b + lr*y[i]
    return w1,w2,b

# %%
w1, w2, b = perceptron(X,y)

# %%
m = -(w1/w2)
c = -(b/w2)
print(m,c)
# Out:
# -43.98253275111108 310.48034934507916

# %%
plt.figure(figsize=(10, 6))
plt.plot(x_input, y_input, color='red', linewidth=3, label='Decision Boundary')
plt.scatter(X[y==1, 0], X[y==1, 1], c='blue', s=100, label='Placed')
plt.scatter(X[y==-1, 0], X[y==-1, 1], c='green', s=100, label='Not Placed')
plt.xlabel('CGPA')
plt.ylabel('Resume Score')
plt.title('Placement Decision Boundary')
plt.xlim(X[:, 0].min() - 1, X[:, 0].max() + 1)
plt.ylim(X[:, 1].min() - 1, X[:, 1].max() + 1)
plt.legend()
plt.show()
